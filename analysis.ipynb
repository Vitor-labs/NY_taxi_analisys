# %%
import pyarrow.parquet as pq
import pandas as pd
from sqlalchemy import create_engine
from time import time

DATA_URL = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet"
DB_URL = "postgresql://root:root@localhost:5432/ny_taxi"

engine = create_engine(DB_URL)

# %%
trips = pd.read_parquet(DATA_URL)
trips.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0  \
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID
# 0           0.97         1.0                  N           161           141  \
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount
# 0             2          9.3   1.00      0.5        0.00           0.0  \
# 1             1          7.9   1.00      0.5        4.00           0.0
# 2             1         14.9   1.00      0.5       15.00           0.0
# 3             1         12.1   7.25      0.5        0.00           0.0
# 4             1         11.4   1.00      0.5        3.28           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee
# 0                    1.0         14.30                   2.5         0.00
# 1                    1.0         16.90                   2.5         0.00
# 2                    1.0         34.90                   2.5         0.00
# 3                    1.0         20.85                   0.0         1.25
# 4                    1.0         19.68                   2.5         0.00

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(trips, name='yellow_taxi_date', con=engine))
# Out:
# CREATE TABLE yellow_taxi_date (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
trips.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
print("Inserting chuncks...")

batch_size = 10000
total_rows = len(trips)
num_batches = total_rows // batch_size + 1

for i in range(num_batches):
    t_start = time()
    start = i * batch_size
    end = min((i + 1) * batch_size, total_rows)

    batch_data = trips.iloc[start:end]

    batch_data.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
    t_end = time()

    print(f'...Inserted {end} lines, took {t_end - t_start}s')
# Out:
# Inserting chuncks...
# ...Inserted 10000 lines, took -3.191936492919922s
# ...Inserted 20000 lines, took -2.6458539962768555s
# ...Inserted 30000 lines, took -2.444611072540283s
# ...Inserted 40000 lines, took -2.7511343955993652s
# ...Inserted 50000 lines, took -2.884680986404419s
# ...Inserted 60000 lines, took -3.549940347671509s
# ...Inserted 70000 lines, took -4.088824033737183s
# ...Inserted 80000 lines, took -3.391531467437744s
# ...Inserted 90000 lines, took -3.0700459480285645s
# ...Inserted 100000 lines, took -4.164892911911011s
# ...Inserted 110000 lines, took -4.342038631439209s
# ...Inserted 120000 lines, took -4.597356557846069s
# ...Inserted 130000 lines, took -5.284945964813232s
# ...Inserted 140000 lines, took -4.746995449066162s
# ...Inserted 150000 lines, took -4.692772150039673s
# ...Inserted 160000 lines, took -5.268951416015625s
# ...Inserted 170000 lines, took -3.315607786178589s
# ...Inserted 180000 lines, took -4.1458234786987305s
# ...Inserted 190000 lines, took -2.733144760131836s
# ...Inserted 200000 lines, took -2.852126359939575s
# ...Inserted 210000 lines, took -5.364795684814453s
# ...Inserted 220000 lines, took -4.353753089904785s
# ...Inserted 230000 lines, took -6.229467153549194s
# ...Inserted 240000 lines, took -6.4994142055511475s
# ...Inserted 250000 lines, took -3.9716105461120605s
# ...Inserted 260000 lines, took -4.884905815124512s
# ...Inserted 270000 lines, took -4.057356834411621s
# ...Inserted 280000 lines, took -3.989373207092285s
# ...Inserted 290000 lines, took -4.241005182266235s
# ...Inserted 300000 lines, took -3.9562928676605225s
# ...Inserted 310000 lines, took -3.881606101989746s
# ...Inserted 320000 lines, took -3.952115297317505s
# ...Inserted 330000 lines, took -3.845088481903076s
# ...Inserted 340000 lines, took -4.277102470397949s
# ...Inserted 350000 lines, took -5.122459411621094s
# ...Inserted 360000 lines, took -4.005485534667969s
# ...Inserted 370000 lines, took -4.491332530975342s
# ...Inserted 380000 lines, took -3.878875494003296s
# ...Inserted 390000 lines, took -3.728274345397949s
# ...Inserted 400000 lines, took -3.8655080795288086s
# ...Inserted 410000 lines, took -4.436952114105225s
# ...Inserted 420000 lines, took -3.814728260040283s
# ...Inserted 430000 lines, took -3.638467311859131s
# ...Inserted 440000 lines, took -3.8779053688049316s
# ...Inserted 450000 lines, took -4.104081392288208s
# ...Inserted 460000 lines, took -3.996947765350342s
# ...Inserted 470000 lines, took -3.6739323139190674s
# ...Inserted 480000 lines, took -3.8836538791656494s
# ...Inserted 490000 lines, took -3.811061382293701s
# ...Inserted 500000 lines, took -4.15049934387207s
# ...Inserted 510000 lines, took -5.517637014389038s
# ...Inserted 520000 lines, took -3.9642515182495117s
# ...Inserted 530000 lines, took -4.40878438949585s
# ...Inserted 540000 lines, took -4.102038621902466s
# ...Inserted 550000 lines, took -3.936521053314209s
# ...Inserted 560000 lines, took -3.8202438354492188s
# ...Inserted 570000 lines, took -4.691727876663208s
# ...Inserted 580000 lines, took -3.6309704780578613s
# ...Inserted 590000 lines, took -3.8467836380004883s
# ...Inserted 600000 lines, took -4.00065279006958s
# ...Inserted 610000 lines, took -4.70901346206665s
# ...Inserted 620000 lines, took -3.7772929668426514s
# ...Inserted 630000 lines, took -3.9984242916107178s
# ...Inserted 640000 lines, took -3.691084861755371s
# ...Inserted 650000 lines, took -3.703420639038086s
# ...Inserted 660000 lines, took -3.1646461486816406s
# ...Inserted 670000 lines, took -2.927973747253418s
# ...Inserted 680000 lines, took -2.7045164108276367s
# ...Inserted 690000 lines, took -2.8209478855133057s
# ...Inserted 700000 lines, took -3.3408377170562744s
# ...Inserted 710000 lines, took -3.0831830501556396s
# ...Inserted 720000 lines, took -2.8098697662353516s
# ...Inserted 730000 lines, took -2.8835577964782715s
# ...Inserted 740000 lines, took -2.9525821208953857s
# ...Inserted 750000 lines, took -3.36800217628479s
# ...Inserted 760000 lines, took -2.835570812225342s
# ...Inserted 770000 lines, took -2.7936527729034424s
# ...Inserted 780000 lines, took -2.743119239807129s
# ...Inserted 790000 lines, took -2.691009521484375s
# ...Inserted 800000 lines, took -2.978541851043701s
# ...Inserted 810000 lines, took -2.9019298553466797s
# ...Inserted 820000 lines, took -3.136716365814209s
# ...Inserted 830000 lines, took -2.7818191051483154s
# ...Inserted 840000 lines, took -3.315538167953491s
# ...Inserted 850000 lines, took -3.653048038482666s
# ...Inserted 860000 lines, took -3.131148338317871s
# ...Inserted 870000 lines, took -2.9907422065734863s
# ...Inserted 880000 lines, took -2.6716206073760986s
# ...Inserted 890000 lines, took -2.8583731651306152s
# ...Inserted 900000 lines, took -3.0559120178222656s
# ...Inserted 910000 lines, took -2.7347664833068848s
# ...Inserted 920000 lines, took -2.997058391571045s
# ...Inserted 930000 lines, took -3.001492977142334s
# ...Inserted 940000 lines, took -2.7470650672912598s
# ...Inserted 950000 lines, took -2.963557720184326s
# ...Inserted 960000 lines, took -2.8448357582092285s
# ...Inserted 970000 lines, took -3.049487590789795s
# ...Inserted 980000 lines, took -2.7321455478668213s
# ...Inserted 990000 lines, took -2.6978232860565186s
# ...Inserted 1000000 lines, took -2.631057024002075s
# ...Inserted 1010000 lines, took -2.5758280754089355s
# ...Inserted 1020000 lines, took -2.832765817642212s
# ...Inserted 1030000 lines, took -2.798633098602295s
# ...Inserted 1040000 lines, took -3.0589914321899414s
# ...Inserted 1050000 lines, took -2.6356935501098633s
# ...Inserted 1060000 lines, took -2.5027403831481934s
# ...Inserted 1070000 lines, took -3.1528022289276123s
# ...Inserted 1080000 lines, took -3.236402988433838s
# ...Inserted 1090000 lines, took -3.1088991165161133s
# ...Inserted 1100000 lines, took -3.2669589519500732s
# ...Inserted 1110000 lines, took -3.028142213821411s
# ...Inserted 1120000 lines, took -2.855255365371704s
# ...Inserted 1130000 lines, took -2.8446226119995117s
# ...Inserted 1140000 lines, took -2.8868165016174316s
# ...Inserted 1150000 lines, took -2.5942885875701904s
# ...Inserted 1160000 lines, took -3.8304333686828613s
# ...Inserted 1170000 lines, took -2.871244430541992s
# ...Inserted 1180000 lines, took -4.0558013916015625s
# ...Inserted 1190000 lines, took -4.555179119110107s
# ...Inserted 1200000 lines, took -4.09722638130188s
# ...Inserted 1210000 lines, took -3.9031336307525635s
# ...Inserted 1220000 lines, took -3.8906993865966797s
# ...Inserted 1230000 lines, took -3.7565970420837402s
# ...Inserted 1240000 lines, took -4.582637071609497s
# ...Inserted 1250000 lines, took -4.271936416625977s
# ...Inserted 1260000 lines, took -4.2111639976501465s
# ...Inserted 1270000 lines, took -3.7366466522216797s
# ...Inserted 1280000 lines, took -3.804269313812256s
# ...Inserted 1290000 lines, took -4.533237457275391s
# ...Inserted 1300000 lines, took -4.051063537597656s
# ...Inserted 1310000 lines, took -4.272653579711914s
# ...Inserted 1320000 lines, took -4.206614971160889s
# ...Inserted 1330000 lines, took -3.9465384483337402s
# ...Inserted 1340000 lines, took -4.177950143814087s
# ...Inserted 1350000 lines, took -3.8355205059051514s
# ...Inserted 1360000 lines, took -4.3876953125s
# ...Inserted 1370000 lines, took -3.873455762863159s
# ...Inserted 1380000 lines, took -4.0894811153411865s
# ...Inserted 1390000 lines, took -4.050945520401001s
# ...Inserted 1400000 lines, took -4.282636880874634s
# ...Inserted 1410000 lines, took -4.21455454826355s
# ...Inserted 1420000 lines, took -3.7779557704925537s
# ...Inserted 1430000 lines, took -3.9823830127716064s
# ...Inserted 1440000 lines, took -4.191624641418457s
# ...Inserted 1450000 lines, took -3.9361889362335205s
# ...Inserted 1460000 lines, took -4.021526336669922s
# ...Inserted 1470000 lines, took -4.051588535308838s
# ...Inserted 1480000 lines, took -4.186128616333008s
# ...Inserted 1490000 lines, took -3.97286057472229s
# ...Inserted 1500000 lines, took -3.775768756866455s
# ...Inserted 1510000 lines, took -4.681624412536621s
# ...Inserted 1520000 lines, took -3.7394816875457764s
# ...Inserted 1530000 lines, took -3.9866671562194824s
# ...Inserted 1540000 lines, took -3.703909397125244s
# ...Inserted 1550000 lines, took -3.663775682449341s
# ...Inserted 1560000 lines, took -4.434380769729614s
# ...Inserted 1570000 lines, took -3.781036138534546s
# ...Inserted 1580000 lines, took -4.270604372024536s
# ...Inserted 1590000 lines, took -3.8236825466156006s
# ...Inserted 1600000 lines, took -3.752274513244629s
# ...Inserted 1610000 lines, took -3.78532338142395s
# ...Inserted 1620000 lines, took -3.8343987464904785s
# ...Inserted 1630000 lines, took -4.224987983703613s
# ...Inserted 1640000 lines, took -4.055248498916626s
# ...Inserted 1650000 lines, took -4.033522367477417s
# ...Inserted 1660000 lines, took -4.065500974655151s
# ...Inserted 1670000 lines, took -4.986494541168213s
# ...Inserted 1680000 lines, took -4.173935413360596s
# ...Inserted 1690000 lines, took -3.7625551223754883s
# ...Inserted 1700000 lines, took -3.6010563373565674s
# ...Inserted 1710000 lines, took -3.5783002376556396s
# ...Inserted 1720000 lines, took -3.8214900493621826s
# ...Inserted 1730000 lines, took -4.2720019817352295s
# ...Inserted 1740000 lines, took -4.001078844070435s
# ...Inserted 1750000 lines, took -3.9599506855010986s
# ...Inserted 1760000 lines, took -3.808253288269043s
# ...Inserted 1770000 lines, took -3.9568889141082764s
# ...Inserted 1780000 lines, took -3.953667402267456s
# ...Inserted 1790000 lines, took -4.059200763702393s
# ...Inserted 1800000 lines, took -3.920783281326294s
# ...Inserted 1810000 lines, took -3.9672117233276367s
# ...Inserted 1820000 lines, took -3.857538938522339s
# ...Inserted 1830000 lines, took -4.280503034591675s
# ...Inserted 1840000 lines, took -3.8109405040740967s
# ...Inserted 1850000 lines, took -4.1633100509643555s
# ...Inserted 1860000 lines, took -4.78178596496582s
# ...Inserted 1870000 lines, took -4.381781578063965s
# ...Inserted 1880000 lines, took -3.9088714122772217s
# ...Inserted 1890000 lines, took -3.7003018856048584s
# ...Inserted 1900000 lines, took -3.8031113147735596s
# ...Inserted 1910000 lines, took -3.4071927070617676s
# ...Inserted 1920000 lines, took -3.4447860717773438s
# ...Inserted 1930000 lines, took -3.4697093963623047s
# ...Inserted 1940000 lines, took -3.71443510055542s
# ...Inserted 1950000 lines, took -3.8986265659332275s
# ...Inserted 1960000 lines, took -3.78641676902771s
# ...Inserted 1970000 lines, took -3.9807982444763184s
# ...Inserted 1980000 lines, took -4.3189568519592285s
# ...Inserted 1990000 lines, took -3.531073570251465s
# ...Inserted 2000000 lines, took -3.5591607093811035s
# ...Inserted 2010000 lines, took -3.6919326782226562s
# ...Inserted 2020000 lines, took -3.361070156097412s
# ...Inserted 2030000 lines, took -3.734208583831787s
# ...Inserted 2040000 lines, took -3.64951753616333s
# ...Inserted 2050000 lines, took -3.4791510105133057s
# ...Inserted 2060000 lines, took -4.248110055923462s
# ...Inserted 2070000 lines, took -3.6179139614105225s
# ...Inserted 2080000 lines, took -3.666755437850952s
# ...Inserted 2090000 lines, took -3.613741874694824s
# ...Inserted 2100000 lines, took -3.743546485900879s
# ...Inserted 2110000 lines, took -3.4303371906280518s
# ...Inserted 2120000 lines, took -3.50057053565979s
# ...Inserted 2130000 lines, took -3.6686058044433594s
# ...Inserted 2140000 lines, took -3.9751710891723633s
# ...Inserted 2150000 lines, took -3.9049947261810303s
# ...Inserted 2160000 lines, took -3.5617642402648926s
# ...Inserted 2170000 lines, took -3.905409336090088s
# ...Inserted 2180000 lines, took -3.0274038314819336s
# ...Inserted 2190000 lines, took -3.0121588706970215s
# ...Inserted 2200000 lines, took -2.9885172843933105s
# ...Inserted 2210000 lines, took -3.0840249061584473s
# ...Inserted 2220000 lines, took -3.0381596088409424s
# ...Inserted 2230000 lines, took -3.0833945274353027s
# ...Inserted 2240000 lines, took -3.1747639179229736s
# ...Inserted 2250000 lines, took -3.5441887378692627s
# ...Inserted 2260000 lines, took -3.0066885948181152s
# ...Inserted 2270000 lines, took -2.712693929672241s
# ...Inserted 2280000 lines, took -2.8485634326934814s
# ...Inserted 2290000 lines, took -2.845974922180176s
# ...Inserted 2300000 lines, took -2.846465826034546s
# ...Inserted 2310000 lines, took -2.7980854511260986s
# ...Inserted 2320000 lines, took -2.814343214035034s
# ...Inserted 2330000 lines, took -2.9305832386016846s
# ...Inserted 2340000 lines, took -2.774895668029785s
# ...Inserted 2350000 lines, took -4.857147693634033s
# ...Inserted 2360000 lines, took -4.4255101680755615s
# ...Inserted 2370000 lines, took -3.943298816680908s
# ...Inserted 2380000 lines, took -3.8359768390655518s
# ...Inserted 2390000 lines, took -4.080971717834473s
# ...Inserted 2400000 lines, took -4.049021005630493s
# ...Inserted 2410000 lines, took -4.132814645767212s
# ...Inserted 2420000 lines, took -3.7597804069519043s
# ...Inserted 2430000 lines, took -3.756922483444214s
# ...Inserted 2440000 lines, took -3.785907030105591s
# ...Inserted 2450000 lines, took -3.6308271884918213s
# ...Inserted 2460000 lines, took -3.698688507080078s
# ...Inserted 2470000 lines, took -3.9098124504089355s
# ...Inserted 2480000 lines, took -3.529500961303711s
# ...Inserted 2490000 lines, took -3.4473588466644287s
# ...Inserted 2500000 lines, took -3.5379292964935303s
# ...Inserted 2510000 lines, took -3.8259501457214355s
# ...Inserted 2520000 lines, took -3.8323495388031006s
# ...Inserted 2530000 lines, took -4.232669353485107s
# ...Inserted 2540000 lines, took -3.748290538787842s
# ...Inserted 2550000 lines, took -3.809657335281372s
# ...Inserted 2560000 lines, took -3.737884759902954s
# ...Inserted 2570000 lines, took -3.8476719856262207s
# ...Inserted 2580000 lines, took -3.951540946960449s
# ...Inserted 2590000 lines, took -3.6952927112579346s
# ...Inserted 2600000 lines, took -3.6251182556152344s
# ...Inserted 2610000 lines, took -3.763502597808838s
# ...Inserted 2620000 lines, took -3.886995553970337s
# ...Inserted 2630000 lines, took -3.859062671661377s
# ...Inserted 2640000 lines, took -4.140527248382568s
# ...Inserted 2650000 lines, took -3.8320376873016357s
# ...Inserted 2660000 lines, took -4.2374491691589355s
# ...Inserted 2670000 lines, took -4.040767192840576s
# ...Inserted 2680000 lines, took -5.4985511302948s
# ...Inserted 2690000 lines, took -4.544613361358643s
# ...Inserted 2700000 lines, took -4.2811713218688965s
# ...Inserted 2710000 lines, took -4.782235622406006s
# ...Inserted 2720000 lines, took -4.722736120223999s
# ...Inserted 2730000 lines, took -4.108942031860352s
# ...Inserted 2740000 lines, took -3.889397621154785s
# ...Inserted 2750000 lines, took -4.075281143188477s
# ...Inserted 2760000 lines, took -4.27750301361084s
# ...Inserted 2770000 lines, took -3.837252378463745s
# ...Inserted 2780000 lines, took -4.755847215652466s
# ...Inserted 2790000 lines, took -3.7661283016204834s
# ...Inserted 2800000 lines, took -3.924008369445801s
# ...Inserted 2810000 lines, took -4.44695782661438s
# ...Inserted 2820000 lines, took -4.3322083950042725s
# ...Inserted 2830000 lines, took -3.850757598876953s
# ...Inserted 2840000 lines, took -4.199915885925293s
# ...Inserted 2850000 lines, took -4.364933252334595s
# ...Inserted 2860000 lines, took -3.910627603530884s
# ...Inserted 2870000 lines, took -5.862434387207031s
# ...Inserted 2880000 lines, took -4.595679044723511s
# ...Inserted 2890000 lines, took -3.6000900268554688s
# ...Inserted 2900000 lines, took -3.7568752765655518s
# ...Inserted 2910000 lines, took -3.664766550064087s
# ...Inserted 2920000 lines, took -3.7446913719177246s
# ...Inserted 2930000 lines, took -4.068868160247803s
# ...Inserted 2940000 lines, took -4.9373438358306885s
# ...Inserted 2950000 lines, took -4.029201984405518s
# ...Inserted 2960000 lines, took -4.976085662841797s
# ...Inserted 2970000 lines, took -4.131664276123047s
# ...Inserted 2980000 lines, took -3.888263463973999s
# ...Inserted 2990000 lines, took -4.258833408355713s
# ...Inserted 3000000 lines, took -3.974385976791382s
# ...Inserted 3010000 lines, took -3.635043144226074s
# ...Inserted 3020000 lines, took -3.4433844089508057s
# ...Inserted 3030000 lines, took -4.54776406288147s
# ...Inserted 3040000 lines, took -3.743435859680176s
# ...Inserted 3050000 lines, took -3.4515984058380127s
# ...Inserted 3060000 lines, took -4.198113441467285s
# ...Inserted 3066766 lines, took -2.5807044506073s
